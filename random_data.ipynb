# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as pyt 

# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(30,6))

# %%
df.head()
# Out:
#           0         1         2         3         4         5
# 0  0.345974  0.428811  0.669209  0.144727  0.830173  0.264970
# 1  0.717604  0.192715  0.331275  0.230363  0.306485  0.463927
# 2  0.285684  0.468724  0.546996  0.640671  0.691154  0.792177
# 3  0.404475  0.085592  0.236514  0.427340  0.449261  0.712789
# 4  0.600466  0.855407  0.553949  0.922742  0.867844  0.786485

# %%
df.shape
# Out:
# (30, 6)

# %%
df.describe()
# Out:
#                0          1          2          3          4          5
# count  30.000000  30.000000  30.000000  30.000000  30.000000  30.000000
# mean    0.539452   0.431620   0.492972   0.465383   0.494624   0.460131
# std     0.279793   0.281202   0.268036   0.286910   0.298770   0.290869
# min     0.020612   0.034563   0.004109   0.063946   0.019276   0.015032
# 25%     0.349997   0.193995   0.302816   0.181080   0.279446   0.205033
# 50%     0.531243   0.417172   0.468892   0.425673   0.469892   0.456141
# 75%     0.756416   0.630804   0.671932   0.683200   0.716227   0.738602
# max     0.987948   0.986827   0.959595   0.948802   0.989465   0.901680

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       30 non-null     float64
#  1   1       30 non-null     float64
#  2   2       30 non-null     float64
#  3   3       30 non-null     float64
#  4   4       30 non-null     float64
#  5   5       30 non-null     float64
# dtypes: float64(6)
# memory usage: 1.5 KB

# %%
df.to_csv('data/randomData.csv')

# %%
df.plot(kind='bar', figsize=(30,6))
# Out:
# <Axes: >

# %%
udf = df.iloc[0,:]
udf.plot(kind='pie', figsize=(6,6), ylabel='')
# Out:
# <Axes: >

# %%
df.columns = ['One', 'Two', 'Three', 'Four', 'Five', 'Six']
df.to_csv('data/randomData.csv')

# %%
df.head(5)
# Out:
#         One       Two     Three      Four      Five       Six
# 0  0.345974  0.428811  0.669209  0.144727  0.830173  0.264970
# 1  0.717604  0.192715  0.331275  0.230363  0.306485  0.463927
# 2  0.285684  0.468724  0.546996  0.640671  0.691154  0.792177
# 3  0.404475  0.085592  0.236514  0.427340  0.449261  0.712789
# 4  0.600466  0.855407  0.553949  0.922742  0.867844  0.786485

# %%
odf = df[['One', 'Two']]
odf.plot(kind='hist', figsize=(7, 8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
corrdf = df.corr()
corrdf
corrdf.plot(kind='barh', figsize=(5,6))
# Out:
# <Axes: >
