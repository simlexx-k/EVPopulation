# %% [markdown]
# Executional Case of Data Analysis on sample data from
# https://catalog.data.gov/dataset/electric-vehicle-population-data on Electrical Vehicle
# Population Data.
# This workplace can be found at [github repo]
#
# Disclaimer: The DataFrame has an error with headers having spaces in between, so we'll just have that space indicated whener we are referring to any element in the csv until we fix the error.

# %%
#Running basic module imports
import numpy as np 
import matplotlib.pyplot as pyp 
import pandas as pd

# %%
ev = pd.read_csv('data/evdata.csv')
# Out:
# C:\Users\simon\AppData\Local\Temp\ipykernel_1136\3427360624.py:1: DtypeWarning: Columns (4,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   ev = pd.read_csv('data/evdata.csv')

# %%
#Let's display some head data of our dataframe
ev.head()
# Out:
#           VIN   County                 City                       State   \
# 0  5YJYGDEF5L   Thurston               Lacey                      WA
# 1  1N4BZ1CP1K   King                   Sammamish                  WA
# 2  5YJXCDE28G   King                   Kent                       WA
# 3  JHMZC5F37M   Kitsap                 Poulsbo                    WA
# 4  WA1F2AFY4P   Thurston               Olympia                    WA
#
#    Postal_Code   Model_Year   Make                   \
# 0        98516          2020  TESLA
# 1        98074          2019  NISSAN
# 2        98031          2016  TESLA
# 3        98370          2021  HONDA
# 4        98501          2023  AUDI
#
#    Model                                    Ev_Type                    \
# 0  MODEL Y                    Battery Electric Vehicle (BEV)
# 1  LEAF                       Battery Electric Vehicle (BEV)
# 2  MODEL X                    Battery Electric Vehicle (BEV)
# ...

# %%
#Get the shape of our dataframe [rows and columns]
#We have 163003 rows with 17 columns
ev.shape
# Out:
# (163003, 17)

# %%
#Some insight into the dataframe

ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163003 entries, 0 to 163002
# Data columns (total 17 columns):
#  #   Column                                                                                                             Non-Null Count   Dtype
# ---  ------                                                                                                             --------------   -----
#  0   VIN                                                                                                                163003 non-null  object
#  1   County                                                                                                             163003 non-null  object
#  2   City                                                                                                               163003 non-null  object
#  3   State                                                                                                              163003 non-null  object
# ...

# %%
#Some description of the dataframe

ev.describe
# Out:
# <bound method NDFrame.describe of                VIN   County                 City                       State   \
# 0       5YJYGDEF5L   Thurston               Lacey                      WA
# 1       1N4BZ1CP1K   King                   Sammamish                  WA
# 2       5YJXCDE28G   King                   Kent                       WA
# 3       JHMZC5F37M   Kitsap                 Poulsbo                    WA
# 4       WA1F2AFY4P   Thurston               Olympia                    WA
# ...             ...                    ...                        ...     ...
# 162998  7SAYGAEE6P   Whatcom                Bellingham                 WA
# 162999  7SAYGDEE4P   King                   Vashon                     WA
# 163000  7SAYGDEE0P   Snohomish              Bothell                    WA
# 163001  JTDKARFP7H   Pierce                 Spanaway                   WA
# 163002  3FMTK3SU7N   Spokane                Spokane                    WA
#
# ...

# %%
#We can also get a description of a certain element of the dataframe, like Model_Year

ev['Model_Year '].describe()
# Out:
# count    163003.000000
# mean       2020.258449
# std           3.005057
# min        1997.000000
# 25%        2018.000000
# 50%        2021.000000
# 75%        2023.000000
# max        2024.000000
# Name: Model_Year , dtype: float64

# %%
#Let's get some crunchy data
#Get the number of vehicles made per year
# Get unique number of makes in the DataFrame
total_make = ev['Make                 '].value_counts()
total_make
# Out:
# Make
# TESLA                    73587
# NISSAN                   13799
# CHEVROLET                12868
# FORD                      8284
# BMW                       7018
# KIA                       6859
# TOYOTA                    5684
# VOLKSWAGEN                4536
# JEEP                      3893
# HYUNDAI                   3885
# VOLVO                     3835
# AUDI                      3349
# RIVIAN                    3166
# CHRYSLER                  2872
# MERCEDES-BENZ             1274
# PORSCHE                   1082
# MITSUBISHI                 916
# MINI                       845
# POLESTAR                   832
# HONDA                      822
# FIAT                       801
# SUBARU                     751
# MAZDA                      343
# SMART                      276
# LEXUS                      255
# LINCOLN                    247
# CADILLAC                   218
# JAGUAR                     218
# LUCID                      216
# GENESIS                    144
# ...

# %%
#Find the mean number of vehicles made each year

max_year = ev['Model_Year '].max()
min_year = ev['Model_Year '].min()
total_years = max_year - min_year

total_vehicles = ev['Model                    '].value_counts()

mean_vehicles = total_vehicles/total_years
mean_vehicles
# Out:
# Model
# MODEL Y                      1171.851852
# MODEL 3                      1068.444444
# LEAF                          491.259259
# MODEL S                       284.074074
# BOLT EV                       232.555556
#                                 ...
# XM                              0.037037
# HUMMER EV PICKUP                0.037037
# S-10 PICKUP                     0.037037
# BENTAYGA                        0.037037
# MX-30                           0.037037
# Name: count, Length: 136, dtype: float64

# %%
#Sort the dataframe by the most popular make

sort_models = ev.sort_values(['Make                 '], ascending = False).head(5)
sort_models
# Out:
#                VIN   County                 City                       State   \
# 115308  1W9WL21B6A   Pierce                 Tacoma                     WA
# 94231   1W9WL21BXA   Spokane                Spokane                    WA
# 21683   1W9WL21B6A   Thurston               Olympia                    WA
# 77273   YV4ED3UR4M   King                   Seattle                    WA
# 39275   YV4ED3GM9P   King                   Seatac                     WA
#
#         Postal_Code   Model_Year   Make                   \
# 115308         98406         2010  WHEEGO ELECTRIC CARS
# 94231          99223         2010  WHEEGO ELECTRIC CARS
# 21683         98501          2010  WHEEGO ELECTRIC CARS
# 77273          98102         2021  VOLVO
# 39275          98148         2023  VOLVO
#
#         Model                                    Ev_Type                    \
# 115308  WHEEGO                     Plug-in Hybrid Electric Vehicle (PHEV)
# ...
