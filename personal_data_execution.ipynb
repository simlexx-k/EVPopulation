# %% [markdown]
# # Personal Data Mockup Using Mockaroo
#
# This Jupyter Notebook demonstrates the usage of a personal data mockup generated by Mockaroo.
#
# Notebook developed by Simon Kosgei ['https://github.com/simlexx-k']

# %%
#Loading Data

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#from scipy.stats import gaussian_kde

# %matplotlib inline

# %%
pdata = pd.read_csv('data/personal_data.csv')

print('Data Overview:')
pdata.head()
# Out:
# Data Overview:
#    id     first_name       last_name        \
# 0      1  Stanton          Rabat
# 1      2  Gianni           Pavic
# 2      3  Allin            Barnwall
# 3      4  Beckie           Gummary
# 4      5  Kingston         Brimilcombe
#
#    email                                 gender        balance     \
# 0  srabat0@1und1.de                      Genderfluid   $11585.92
# 1  gpavic1@upenn.edu                     Bigender      $25221.83
# 2  abarnwall2@spotify.com                Male          $17884.25
# 3  bgummary3@nydailynews.com             Female        $2535.83
# 4  kbrimilcombe4@bloomberg.com           Agender       $24351.33
#
#    dob          vehicle         family_size
# 0  10/29/1979   Toyota                    5
# 1  11/6/1985    Mitsubishi                5
# 2  4/23/1974    Chrysler                  2
# 3  2/4/1993     Acura                     7
# 4  9/10/1987    Chevrolet                 9

# %%
print('Basic Statistical Information:')
pdata.describe()
# Out:
# Basic Statistical Information:
#              id     family_size
# count  1000.000000  1000.000000
# mean    500.500000     5.523000
# std     288.819436     2.840341
# min       1.000000     1.000000
# 25%     250.750000     3.000000
# 50%     500.500000     6.000000
# 75%     750.250000     8.000000
# max    1000.000000    10.000000

# %%
print('Brief Information:')
pdata.info()
# Out:
# Brief Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    1000 non-null   int64
#  1   first_name                            1000 non-null   object
#  2   last_name                             1000 non-null   object
#  3   email                                 1000 non-null   object
#  4   gender                                1000 non-null   object
#  5   balance                               1000 non-null   object
#  6   dob                                   1000 non-null   object
#  7   vehicle                               1000 non-null   object
#  8   family_size                           1000 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 70.4+ KB

# %%
#Define datapoints

x = pdata['gender      '].isin(['Female', 'Male'])
y = pdata['family_size']
# Plot the data
plt.plot(x, y, label='Gender vs Family Size')
plt.title('Gender vs Family Size Data Visualization')
plt.xlabel('X-axis - ' + 'Gender')
plt.ylabel('Y-axis - ' + 'Family Size')
plt.legend()
plt.show()

# %%
#Sort by balance
asort = pdata.sort_values(['balance   '], ascending= False)
print('Data Sorted according to Balances (Descending Order):')
asort
# Out:
# Data Sorted according to Balances (Descending Order):
#      id     first_name       last_name        \
# 129    130  Oran             Bensusan
# 146    147  Mordecai         Goulder
# 905    906  Antonina         Rizzillo
# 612    613  Nathaniel        Clapston
# 432    433  Siffre           Leguay
# ..     ...              ...              ...
# 252    253  Ives             Zorro
# 586    587  Fonz             Chivrall
# 293    294  Catlin           Lilloe
# 587    588  Aubine           Jost
# 971    972  Ber              Bunny
#
#      email                                 gender        balance     \
# 129  obensusan3l@wired.com                 Male          $9976.93
# 146  mgoulder42@aboutads.info              Male          $9970.62
# 905  arizzillop5@angelfire.com             Female        $9957.48
# 612  nclapstonh0@icq.com                   Male          $9945.73
# 432  sleguayc0@skype.com                   Male          $9940.12
# ..                                    ...           ...         ...
# 252  izorro70@bluehost.com                 Male          $10130.00
# 586  fchivrallga@jimdo.com                 Male          $10106.76
# 293  clilloe85@dedecms.com                 Female        $10106.69
# 587  ajostgb@indiatimes.com                Female        $10069.72
# 971  bbunnyqz@ebay.co.uk                   Male          $10018.89
#
#      dob          vehicle         family_size
# 129  3/14/1967    Volkswagen                6
# 146  7/8/1998     Mazda                     9
# 905  11/29/1985   Ford                      1
# 612  8/20/1967    Audi                      7
# 432  6/25/1975    Aston Martin              8
# ..           ...             ...          ...
# 252  8/17/1991    Volkswagen                7
# 586  4/21/1985    Chevrolet                 2
# 293  11/14/1993   Mazda                     7
# 587  11/12/1967   Mercedes-Benz             6
# 971  9/16/1987    Mercury                   9
#
# [1000 rows x 9 columns]

# %%
bsort = pdata.sort_values(['balance   '], ascending= True)
print('Data Sorted according to Balances (Ascending Order):')
bsort
# Out:
# Data Sorted according to Balances (Ascending Order):
#      id     first_name       last_name        \
# 971    972  Ber              Bunny
# 587    588  Aubine           Jost
# 293    294  Catlin           Lilloe
# 586    587  Fonz             Chivrall
# 252    253  Ives             Zorro
# ..     ...              ...              ...
# 432    433  Siffre           Leguay
# 612    613  Nathaniel        Clapston
# 905    906  Antonina         Rizzillo
# 146    147  Mordecai         Goulder
# 129    130  Oran             Bensusan
#
#      email                                 gender        balance     \
# 971  bbunnyqz@ebay.co.uk                   Male          $10018.89
# 587  ajostgb@indiatimes.com                Female        $10069.72
# 293  clilloe85@dedecms.com                 Female        $10106.69
# 586  fchivrallga@jimdo.com                 Male          $10106.76
# 252  izorro70@bluehost.com                 Male          $10130.00
# ..                                    ...           ...         ...
# 432  sleguayc0@skype.com                   Male          $9940.12
# 612  nclapstonh0@icq.com                   Male          $9945.73
# 905  arizzillop5@angelfire.com             Female        $9957.48
# 146  mgoulder42@aboutads.info              Male          $9970.62
# 129  obensusan3l@wired.com                 Male          $9976.93
#
#      dob          vehicle         family_size
# 971  9/16/1987    Mercury                   9
# 587  11/12/1967   Mercedes-Benz             6
# 293  11/14/1993   Mazda                     7
# 586  4/21/1985    Chevrolet                 2
# 252  8/17/1991    Volkswagen                7
# ..           ...             ...          ...
# 432  6/25/1975    Aston Martin              8
# 612  8/20/1967    Audi                      7
# 905  11/29/1985   Ford                      1
# 146  7/8/1998     Mazda                     9
# 129  3/14/1967    Volkswagen                6
#
# [1000 rows x 9 columns]

# %%
#Bar graph plot of vehicles by model
print('Number of specific vehicle models:')
datafig = pdata['vehicle       '].value_counts()
veh_counts = pdata['vehicle       '].value_counts().plot(kind='bar', figsize=[15,8], xlabel='Vehicle', ylabel='Number')
veh_counts
datafig
# Out:
# Number of specific vehicle models:
# vehicle
# Ford              95
# Chevrolet         83
# Dodge             53
# Toyota            48
# GMC               46
# Mitsubishi        44
# Mazda             35
# Mercedes-Benz     35
# Volkswagen        34
# BMW               34
# Pontiac           33
# Audi              32
# Nissan            29
# Buick             28
# Lincoln           25
# Honda             24
# Mercury           23
# Lexus             22
# Jeep              19
# Suzuki            18
# Cadillac          17
# Infiniti          17
# Kia               17
# Acura             16
# Chrysler          15
# Oldsmobile        15
# Hyundai           14
# Volvo             14
# Isuzu             10
# Land Rover         9
# Aston Martin       8
# Jaguar             8
# Subaru             8
# Saab               7
# Lotus              7
# Porsche            7
# Saturn             6
# Maybach            6
# Lamborghini        6
# MINI               5
# Ferrari            3
# Bentley            3
# Maserati           3
# Geo                3
# Eagle              3
# Ram                2
# Hummer             2
# Plymouth           2
# Corbin             1
# Scion              1
# Citroën            1
# Spyker             1
# Merkur             1
# Rambler            1
# Daihatsu           1
# Name: count, dtype: int64

# %%
datafig.head(5).plot(kind='box',figsize=(6,6))
# Out:
# <Axes: >
