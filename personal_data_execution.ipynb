# %% [markdown]
# # Personal Data Mockup Using Mockaroo
#
# This Jupyter Notebook demonstrates the usage of a personal data mockup generated by Mockaroo.
#
# Notebook developed by Simon Kosgei ['https://github.com/simlexx-k']

# %%
#Loading Data

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pdata = pd.read_csv('data/personal_data.csv')

print('Data Overview:')
pdata.head()

# %%
print('Basic Statistical Information:')
pdata.describe()

# %%
print('Brief Information:')
pdata.info()

# %%
#Define datapoints

x = pdata['gender      '].isin(['Female', 'Male'])
y = pdata['family_size']
# Plot the data
plt.plot(x, y, label='Gender vs Family Size')
plt.title('Gender vs Family Size Data Visualization')
plt.xlabel('X-axis - ' + 'Gender')
plt.ylabel('Y-axis - ' + 'Family Size')
plt.legend()
plt.show()

# %%
#Sort by balance
asort = pdata.sort_values(['balance   '], ascending= False)
print('Data Sorted according to Balances (Descending Order):')
asort

# %%
bsort = pdata.sort_values(['balance   '], ascending= True)
print('Data Sorted according to Balances (Ascending Order):')
bsort
# Out:
# Data Sorted according to Balances (Ascending Order):
#      id     first_name       last_name        \
# 971    972  Ber              Bunny
# 587    588  Aubine           Jost
# 293    294  Catlin           Lilloe
# 586    587  Fonz             Chivrall
# 252    253  Ives             Zorro
# ..     ...              ...              ...
# 432    433  Siffre           Leguay
# 612    613  Nathaniel        Clapston
# 905    906  Antonina         Rizzillo
# 146    147  Mordecai         Goulder
# 129    130  Oran             Bensusan
#
#      email                                 gender        balance     \
# 971  bbunnyqz@ebay.co.uk                   Male          $10018.89
# 587  ajostgb@indiatimes.com                Female        $10069.72
# 293  clilloe85@dedecms.com                 Female        $10106.69
# 586  fchivrallga@jimdo.com                 Male          $10106.76
# 252  izorro70@bluehost.com                 Male          $10130.00
# ..                                    ...           ...         ...
# 432  sleguayc0@skype.com                   Male          $9940.12
# 612  nclapstonh0@icq.com                   Male          $9945.73
# 905  arizzillop5@angelfire.com             Female        $9957.48
# 146  mgoulder42@aboutads.info              Male          $9970.62
# 129  obensusan3l@wired.com                 Male          $9976.93
#
#      dob          vehicle         family_size
# 971  9/16/1987    Mercury                   9
# 587  11/12/1967   Mercedes-Benz             6
# 293  11/14/1993   Mazda                     7
# 586  4/21/1985    Chevrolet                 2
# 252  8/17/1991    Volkswagen                7
# ..           ...             ...          ...
# 432  6/25/1975    Aston Martin              8
# 612  8/20/1967    Audi                      7
# 905  11/29/1985   Ford                      1
# 146  7/8/1998     Mazda                     9
# 129  3/14/1967    Volkswagen                6
#
# [1000 rows x 9 columns]

# %%
pdata.sort_values(['vehicle       '], ascending= True).head(5)
# Out:
#      id     first_name       last_name        \
# 933    934  Miller           MacKibbon
# 188    189  Jerrold          Guyonneau
# 661    662  Neel             Towne
# 877    878  Myriam           Flewan
# 938    939  Reynard          Larratt
#
#      email                                 gender        balance     \
# 933  mmackibbonpx@google.com.hk            Male          $22624.07
# 188  jguyonneau58@archive.org              Male          $14709.92
# 661  ntowneid@google.com                   Male          $9739.69
# 877  mflewanod@engadget.com                Female        $15203.62
# 938  rlarrattq2@ucsd.edu                   Male          $11630.07
#
#      dob          vehicle         family_size
# 933  9/20/1971    Acura                     7
# 188  11/29/1978   Acura                    10
# 661  4/19/1981    Acura                     7
# 877  12/7/1990    Acura                     2
# 938  7/16/1995    Acura                     6
